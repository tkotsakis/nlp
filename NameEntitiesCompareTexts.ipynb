# %%
import concurrent.futures
import re
import requests
import random
from collections import defaultdict
import spacy
from spacy import displacy
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

from gensim import corpora
from gensim import models
from gensim import similarities
from gensim.corpora import Dictionary


def get_wikipedia_article(wiki_article, timeout=10):
    '''
    Method that gets a Wikipedia page. 
    '''
    wiki_page_url = 'https://en.wikipedia.org/wiki/'+wiki_article
    response = requests.get(url=wiki_page_url, timeout=timeout)
    article = response.text
    return article


def get_wikipedia_articles(wiki_articles):
    with concurrent.futures.ThreadPoolExecutor(max_workers=16) as executor:
        futures = []
        for article in wiki_articles:
            futures.append(executor.submit(get_wikipedia_article,
                                           wiki_article=article)
                          )
        articles = []
        for future in concurrent.futures.as_completed(futures):
            articles.append(future.result())
    return articles

wiki_articles = [
    # Movies:
    'Rocky_IV', 
    'The_Terminator', 
    'Memento_(film)', 
    'Braveheart',
    'Heat_(1995_film)',
    'Iron_Man_3',
    'Inside_Out_(2015_film)',
    'Rambo_III',
    'Space_Jam',
    # Greek Athletes
    'Vassilis_Spanoulis',
    'Eleftherios_Petrounias',
    'Konstantinos_Kenteris',
    'Stefanos_Tsitsipas',
    'Nikos_Galis',
    'Vasilis_Hatzipanagis',
    'Giannis_Antetokounmpo',
    #Global Athletes and Actors
    'Michael_Jordan', # Michael Jordan , except for famous athlete, was an actor in Space Jam , so it is interesting to see the outcome of our algorithms :-)
    #Actors
    'Al_Pacino',
    'Robert_De_Niro',
    'Mel_Gibson',
    'Robert_Downey_Jr.',
    'Arnold_Schwarzenegger'
    ]

# %%
#Original Corpus from the requested articles
corpus = get_wikipedia_articles(wiki_articles)

# %%
# Functions to clean article

def clean_html(raw_html):
    cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleantext = re.sub(cleanr, ' ', raw_html)
    return cleantext

def clean_punctuation_marks(text):
    return re.sub(r'[^\w\s]',' ', text)

def clean_return_and_tabs(text):
    return re.sub(r'[\n, \t]',' ', text)

def clean_article(data):
    cdata = clean_html(data)
    cdata = clean_punctuation_marks(cdata)
    cdata = clean_return_and_tabs(cdata)
    return cdata

# %%
ordered_articles = []
for c in corpus:
    title_pos = c.find('<title>')+7
    title = c[title_pos:title_pos+50].split(' - ')[0].lower()
    ordered_articles.append(title)

corpus = [clean_article(a) for a in corpus]

# %%
print('Our corpus has', len(corpus), 'documents')
# Out:
# Our corpus has 22 documents

# %%
documents = corpus

# %%
#Helper class to store subjects
class Subjects():

    def __init__(self,document_id,text):
        self.document_id = document_id
        self.text = text

# %%
#Helper class to store name entities
class NameEntities():

    def __init__(self,document_id,text):
        self.document_id = document_id
        self.text = text

# %%
#Helper class to add values to dictionary
class dictionaryManager(dict):
  
    def __init__(self):
        self = dict()
          
    def add(self, key, value):
        self[key] = value

# %%
def extract_sentences(text):
    text = re.split('[.?]', text)
    clean_sent = []
    for sent in text:
        clean_sent.append(sent)
    return clean_sent

# %%
#Load spacy library for English
nlp_english = spacy.load('en_core_web_sm')

#Get words stoplist for english language
stoplist = stopwords.words('english')

# %%
#Get for each article the subjects and store them in a collection with an id as key holder for each document and of course the subjects.
document_subjects = []
subjects=[]
counter=0

for document in documents:
    counter+=1
    words = nltk.tokenize.word_tokenize(document)
    fdist = nltk.FreqDist(words)
    doc = nlp_english(document)
    for token in doc:
        if (re.findall("_SP", token.tag_)):
            continue
        if (token.dep_ == "nsubj"):
            if str(token.text) not in subjects:
                subjects.append(str(token.text).lower().replace(" ", ""))
                document_subjects.append(Subjects(counter,token.text))

# %%
#Iterate through documents collection, get sentence for each one of them and for each sentence store subjects in a new collection
#Store name entities in a dictionary
name_entities = []
entities=[]
sentences=dictionaryManager()
sentence_clear=[]
subjects=[]
counter=0
article_id=0
for article in documents:
    article_id+=1
    doc = nlp_english(article)
    sentence = next(doc.sents) 
    sentence_spans = list(doc.sents)
    for s in sentence_spans:
        if len(s) > 1:
            counter+=100
            sentences.add(counter,clean_article(s.text))
            cleared_text = clean_article(s.text)
            sentence_clear.append(cleared_text)
            if len(s.ents) > 0:
                name_entities.append(NameEntities(article_id,s.ents))
                for e in s.ents:
                    entity = str(e).lower().replace(" ", "")
                    if entity not in entities:
                        entities.append(entity)

# %%
#Create a new collection which is the new intersection between the subjects list and name entities ones.

common_name_entities = set(subjects) & set(entities)
common_name_entities_list = list(common_name_entities)

# %%
#Create new corpus as bag of words in order to calculate the TF-IDF and LDA

texts = [
    [word for word in document.lower().split() if word not in stoplist]
    for document in documents
]

frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [
    [token for token in text if frequency[token] > 1 and len(token) > 1]
    for text in texts
]

dictionary = corpora.Dictionary(texts)
corpus2 = [dictionary.doc2bow(text) for text in texts]

# %%
#Train TF-IDF

tfidf = models.TfidfModel(corpus2)

matrix = similarities.MatrixSimilarity(tfidf[corpus2])

wiki_article = 0
for article_sims in zip(ordered_articles, list(matrix)):
    print('Article',ordered_articles[wiki_article],':')
    sorted_articles = sorted(zip(ordered_articles, article_sims[1]), key= lambda x: -x[1])[1:10]
    for sa in sorted_articles:
        print('\t* ', sa[0], ':', sa[1])
    wiki_article += 1
# Out:
# Article vasilis hatzipanagis :
# 	*  nikos galis : 0.05930094
# 	*  vassilis spanoulis : 0.0392687
# 	*  rocky iv : 0.03643353
# 	*  michael jordan : 0.025617478
# 	*  giannis antetokounmpo : 0.02204236
# 	*  rambo iii : 0.020701978
# 	*  konstantinos kenteris : 0.016912537
# 	*  stefanos tsitsipas : 0.016590396
# 	*  space jam : 0.010364338
# Article eleftherios petrounias :
# 	*  konstantinos kenteris : 0.16971952
# 	*  nikos galis : 0.03894057
# 	*  stefanos tsitsipas : 0.018807884
# 	*  michael jordan : 0.018679997
# 	*  vassilis spanoulis : 0.018407414
# 	*  vasilis hatzipanagis : 0.008787708
# 	*  iron man 3 : 0.007922967
# 	*  al pacino : 0.007455821
# 	*  the terminator : 0.007215864
# Article heat (1995 film) :
# 	*  robert de niro : 0.12506604
# 	*  al pacino : 0.11436206
# 	*  memento (film) : 0.049268425
# 	*  space jam : 0.044434436
# 	*  iron man 3 : 0.042685
# 	*  braveheart : 0.039162166
# 	*  inside out (2015 film) : 0.038378444
# 	*  the terminator : 0.03593237
# 	*  rambo iii : 0.03493269
# Article rocky iv :
# 	*  rambo iii : 0.10510636
# 	*  vasilis hatzipanagis : 0.03643353
# 	*  robert de niro : 0.030893557
# 	*  robert downey jr. : 0.025364988
# 	*  michael jordan : 0.025302762
# 	*  iron man 3 : 0.022904068
# 	*  al pacino : 0.02169516
# 	*  mel gibson : 0.021115042
# 	*  rambo iii : 0.016578995
# 	*  braveheart : 0.015221003
# Article konstantinos kenteris :
# 	*  eleftherios petrounias : 0.16971952
# 	*  nikos galis : 0.06385615
# 	*  vassilis spanoulis : 0.03752528
# 	*  stefanos tsitsipas : 0.02639289
# 	*  michael jordan : 0.025209328
# 	*  space jam : 0.022369435
# 	*  vasilis hatzipanagis : 0.016912537
# 	*  giannis antetokounmpo : 0.014097497
# 	*  al pacino : 0.010283545

# %%
#Michael Jordan has bigger similarity to Giannis Antetokounmpo in comparison with the movie that played him self called Space Jam. That's logical, he is first an athelete and secondly an actor!!

# %%
#LDA
NUM_TOPICS = 20

lda_model = models.LdaModel(corpus2, id2word=dictionary, num_topics=NUM_TOPICS, passes=5)

lda_model.get_topics()[0]

for t in range(NUM_TOPICS):
    print('TOPIC', t,':')
    print(lda_model.show_topic(t))
# Out:
# TOPIC 0 :
# [('retrieved', 0.0055432143), ('mw', 0.0054155895), ('archived', 0.0041476595), ('output', 0.0038850955), ('parser', 0.003427323), ('film', 0.003093446), ('may', 0.0030912515), ('original', 0.0028050216), ('2020', 0.0026860766), ('jordan', 0.0023277428)]
# TOPIC 1 :
# [('retrieved', 0.006094558), ('mw', 0.00456165), ('film', 0.004269564), ('original', 0.0037337008), ('archived', 0.0036826336), ('output', 0.0032380384), ('parser', 0.0028901114), ('may', 0.002555513), ('2020', 0.0025270437), ('2018', 0.002200967)]
# TOPIC 2 :
# [('mw', 0.006326621), ('retrieved', 0.0058673504), ('original', 0.004248489), ('parser', 0.004223608), ('archived', 0.00395002), ('film', 0.0035955107), ('output', 0.003380074), ('jordan', 0.002955665), ('2020', 0.0021982626), ('2010', 0.0021694552)]
# TOPIC 3 :
# [('retrieved', 0.005632358), ('mw', 0.0040267003), ('parser', 0.0038793124), ('output', 0.003665599), ('film', 0.003631018), ('archived', 0.0035872697), ('original', 0.0028912462), ('may', 0.002249602), ('2016', 0.0022443645), ('2010', 0.0021453656)]
# TOPIC 4 :
# [('mw', 0.005493312), ('output', 0.004051636), ('retrieved', 0.003871852), ('parser', 0.0036125677), ('film', 0.003513922), ('films', 0.0029790406), ('original', 0.0028020588), ('archived', 0.002693618), ('jordan', 0.002649968), ('wikipedia', 0.0020554333)]
# TOPIC 5 :
# [('retrieved', 0.005346746), ('archived', 0.0048676357), ('film', 0.0045146765), ('original', 0.0039062283), ('mw', 0.0037905753), ('parser', 0.0035428088), ('output', 0.0030772395), ('films', 0.0027546317), ('2015', 0.0025092887), ('schwarzenegger', 0.0023588252)]
# TOPIC 6 :
# [('mw', 0.02605658), ('parser', 0.018038603), ('output', 0.017430076), ('ext', 0.0077704717), ('vector', 0.007555347), ('greek', 0.0073757456), ('menu', 0.00720781), ('template', 0.006645666), ('portlet', 0.0065323603), ('cs1', 0.006335043)]
# TOPIC 7 :
# [('retrieved', 0.007437533), ('jordan', 0.0049854578), ('mw', 0.0048776427), ('film', 0.004102947), ('output', 0.0039023224), ('parser', 0.003480972), ('archived', 0.0034261518), ('original', 0.0033436383), ('schwarzenegger', 0.0030093149), ('wikipedia', 0.0029554637)]
# TOPIC 19 :
# [('mw', 0.0033226132), ('film', 0.0028852236), ('parser', 0.0022719884), ('original', 0.002091643), ('output', 0.0020822794), ('archived', 0.0020724481), ('retrieved', 0.00203279), ('2020', 0.0019496253), ('jordan', 0.0019273246), ('may', 0.0018378642)]

# %%
sentences_fixed = sentence_clear[70:]

# %%
sentences_cleaned=[]
for sent in sentences_fixed:
    sentences_cleaned.append(extract_sentences(sent))

# %%
random.shuffle(sentences_fixed)

# %%
#Visualize model, highlight dependencies

a = 0
for sentence in sentences_fixed:
    a+=1
    doc = nlp_english(sentence)
    displacy.render(doc, style='dep', jupyter=True, options={'distance': 95})
    if a==10:
        break
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="63d79caf62224ebfb709bda9f094983a-0" class="displacy" width="2140" height="469.5" direction="ltr" style="max-width: none; height: 469.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Steve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="145"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="145">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="240">March</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="240">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="335">23</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="335">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="430"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="525">2009</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="525">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="620">    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="715">Creator</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="715">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="810">James</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="810">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="905">Cameron</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="905">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1000">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1000">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1095">Terminator</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1095">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1190">s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1190">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1285">Origins</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1285">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1380"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1380">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1475">Arnold</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1475">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1570">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1665">Robot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1665">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1760"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1855">Machine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1855">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1950">Wars</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="2045">     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2045">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-63d79caf62224ebfb709bda9f094983a-0-0" stroke-width="2px" d="M70,334.5 C70,2.0 1380.0,2.0 1380.0,334.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-63d79caf62224ebfb709bda9f094983a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,336.5 L62,324.5 78,324.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-63d79caf62224ebfb709bda9f094983a-0-1" stroke-width="2px" d="M70,334.5 C70,287.0 115.0,287.0 115.0,334.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-63d79caf62224ebfb709bda9f094983a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M115.0,336.5 L123.0,324.5 107.0,324.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-63d79caf62224ebfb709bda9f094983a-0-2" stroke-width="2px" d="M165,334.5 C165,287.0 210.0,287.0 210.0,334.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-63d79caf62224ebfb709bda9f094983a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,336.5 L218.0,324.5 202.0,324.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-63d79caf62224ebfb709bda9f094983a-0-3" stroke-width="2px" d="M260,334.5 C260,287.0 305.0,287.0 305.0,334.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-63d79caf62224ebfb709bda9f094983a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</text
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d945bd244b1c45f3af333aadd1ce1469-0" class="displacy" width="1950" height="422.0" direction="ltr" style="max-width: none; height: 422.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="145">fact</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="145">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="240">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="240">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="335">King</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="335">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">Edward</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="525">throws</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="525">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="620">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="715">character</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="715">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="810">out</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="810">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="905">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="905">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="1000">window</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="1095">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1095">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="1190">nothing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1190">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="1285">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1285">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="1380">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1380">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="1475">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1475">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">him</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="1665">being</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1665">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">gay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="332.0">
#     <tspan class="displacy-word" fill="currentColor" x="1855">    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1855">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d945bd244b1c45f3af333aadd1ce1469-0-0" stroke-width="2px" d="M70,287.0 C70,239.5 120.0,239.5 120.0,287.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d945bd244b1c45f3af333aadd1ce1469-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,289.0 L62,277.0 78,277.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d945bd244b1c45f3af333aadd1ce1469-0-1" stroke-width="2px" d="M165,287.0 C165,2.0 1095.0,2.0 1095.0,287.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d945bd244b1c45f3af333aadd1ce1469-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M165,289.0 L157,277.0 173,277.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d945bd244b1c45f3af333aadd1ce1469-0-2" stroke-width="2px" d="M260,287.0 C260,144.5 510.0,144.5 510.0,287.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d945bd244b1c45f3af333aadd1ce1469-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M260,289.0 L252,277.0 268,277.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d945bd244b1c45f3af333aadd1ce1469-0-3" stroke-width="2px" d="M355,287.0 C355,239.5 405.0,239.5 405.0,287.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-
0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M710.0,194.0 L718.0,182.0 702.0,182.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-576fa1112c234058892352e76a812bd4-0-7" stroke-width="2px" d="M830,192.0 C830,144.5 890.0,144.5 890.0,192.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-576fa1112c234058892352e76a812bd4-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M830,194.0 L822,182.0 838,182.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="358792f7291c4495a812883d60504f03-0" class="displacy" width="3375" height="517.0" direction="ltr" style="max-width: none; height: 517.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="145">small</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="145">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="240">farm</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="240">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="335">where</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="335">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">Rocky</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="525">lived</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="525">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="620">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="715">trained</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="715">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="810">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="810">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="905">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="905">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1000"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1000">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1095">Jackson</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1095">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1190">Hole</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1190">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1285">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1285">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1380">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1380">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1475"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1475">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">Grand</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1665">Teton</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1665">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">National</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1855">Park</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1855">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="2045">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2045">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">used</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="2235">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2235">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">filming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="2425">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="2520">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2520">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="2615">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2615">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="2710">outdoor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2710">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="2805">sequences</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2805">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="427.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADP</tspa
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="75f64bf121a34bf19e5e274d64249fd7-0" class="displacy" width="1570" height="469.5" direction="ltr" style="max-width: none; height: 469.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="145">Sydney</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="145">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="240">Morning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="240">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="335">Herald</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="335">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="430">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="525">Retrieved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="525">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="620"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="715">July</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="715">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="810">21</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="810">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="905">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="905">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1000">2010</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1000">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1095">                </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1095">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1190">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1190">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1285">        </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1285">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1380">b</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="379.5">
#     <tspan class="displacy-word" fill="currentColor" x="1475">        </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1475">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75f64bf121a34bf19e5e274d64249fd7-0-0" stroke-width="2px" d="M70,334.5 C70,239.5 310.0,239.5 310.0,334.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75f64bf121a34bf19e5e274d64249fd7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,336.5 L62,324.5 78,324.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75f64bf121a34bf19e5e274d64249fd7-0-1" stroke-width="2px" d="M165,334.5 C165,287.0 210.0,287.0 210.0,334.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75f64bf121a34bf19e5e274d64249fd7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M165,336.5 L157,324.5 173,324.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75f64bf121a34bf19e5e274d64249fd7-0-2" stroke-width="2px" d="M260,334.5 C260,287.0 305.0,287.0 305.0,334.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75f64bf121a34bf19e5e274d64249fd7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M260,336.5 L252,324.5 268,324.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75f64bf121a34bf19e5e274d64249fd7-0-3" stroke-width="2px" d="M355,334.5 C355,287.0 400.0,287.0 400.0,334.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75f64bf121a34bf19e5e274d64249fd7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,336.5 L408.0,324.5 392.0,324.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75f64bf121a34bf19e5e274d64249fd7-0-4" stroke-width="2px" d="M545,334.5 C545,287.0 590.0,287.0 590.0,334.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75f64bf121a34bf19e5e274d64249fd7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M545,336.5 L537,324.5 553,324.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75f64bf121a34bf19e5e274d64249fd7-0-5" stroke-width="2px" d="M355,334.5 C355,239.5 595.0,239.5 595.0,334.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75f64bf121a34bf19e5e274d64249fd7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595.0,336.5 L603.0,324.5 587.0,324.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75f64bf121a34bf19e5e274d64249fd7-0-6" stroke-width="2px" d="M640,334.5 C640,287.0 685.0,287.0 685.0,334.5" fill="none" stroke="currentCo
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d3b25cc40b054616b241500a4da3e780-0" class="displacy" width="4135" height="754.5" direction="ltr" style="max-width: none; height: 754.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">George</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="145"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="145">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="240">January</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="240">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="335">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="335">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="430"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="525">2011</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="525">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="620">    </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="715">Schwarzenegger</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="715">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="810">leaves</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="810">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="905">office</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="905">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="1000">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1000">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="664.5">
#     <tspan class="displacy-word" fill="currentColor" x="1095">huge</tspan>
# ...
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="145">Incredibles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="145">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="240">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="240">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="335">2004</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="335">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">       </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="525">Corpse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="525">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="620">Bride</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="715">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="715">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="810">2005</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="810">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="905">       </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="905">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1000">Cars</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1095">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1095">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1190">2006</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1190">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1285">       </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1285">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1380">Ratatouille</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1475">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1475">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">2007</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1665">       </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1665">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">WALL</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1855">E</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1855">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="2045">2008</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2045">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">       </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="2235">Up</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2235">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="2425">2009</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2425">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="2520">       </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2520">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="2615">Toy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2615">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="2710">Story</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2710">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="2805">3</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2805">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="712.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentCo
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="27570e3d992546eabc253f1f7f6a49da-0" class="displacy" width="1000" height="279.5" direction="ltr" style="max-width: none; height: 279.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="189.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Nominated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="189.5">
#     <tspan class="displacy-word" fill="currentColor" x="145">       </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="145">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="189.5">
#     <tspan class="displacy-word" fill="currentColor" x="240">Independent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="240">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="189.5">
#     <tspan class="displacy-word" fill="currentColor" x="335">Spirit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="335">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="189.5">
#     <tspan class="displacy-word" fill="currentColor" x="430">Award</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="189.5">
#     <tspan class="displacy-word" fill="currentColor" x="525">     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="525">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="189.5">
#     <tspan class="displacy-word" fill="currentColor" x="620">Best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="189.5">
#     <tspan class="displacy-word" fill="currentColor" x="715">Film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="715">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="189.5">
#     <tspan class="displacy-word" fill="currentColor" x="810">     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="810">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="189.5">
#     <tspan class="displacy-word" fill="currentColor" x="905">Memento</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="905">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27570e3d992546eabc253f1f7f6a49da-0-0" stroke-width="2px" d="M70,144.5 C70,2.0 525.0,2.0 525.0,144.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27570e3d992546eabc253f1f7f6a49da-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,146.5 L62,134.5 78,134.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27570e3d992546eabc253f1f7f6a49da-0-1" stroke-width="2px" d="M165,144.5 C165,49.5 330.0,49.5 330.0,144.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27570e3d992546eabc253f1f7f6a49da-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M165,146.5 L157,134.5 173,134.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27570e3d992546eabc253f1f7f6a49da-0-2" stroke-width="2px" d="M260,144.5 C260,97.0 325.0,97.0 325.0,144.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27570e3d992546eabc253f1f7f6a49da-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M260,146.5 L252,134.5 268,134.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27570e3d992546eabc253f1f7f6a49da-0-3" stroke-width="2px" d="M355,144.5 C355,49.5 520.0,49.5 520.0,144.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27570e3d992546eabc253f1f7f6a49da-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M355,146.5 L347,134.5 363,134.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27570e3d992546eabc253f1f7f6a49da-0-4" stroke-width="2px" d="M450,144.5 C450,97.0 515.0,97.0 515.0,144.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27570e3d992546eabc253f1f7f6a49da-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450,146.5 L442,134.5 458,134.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27570e3d992546eabc253f1f7f6a49da-0-5" stroke-width="2px" d="M545,144.5 C545,49.5 710.0,49.5 710.0,144.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27570e3d992546eabc253f1f7f6a49da-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M545,146.5 L537,134.5 553,134.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27570e3d992546eabc253f1f7f6a49da-0-6" stroke-width="2px" d="M640,144.5 C640,97.0 705.0,97.0 705.0,144.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27570e3d992546eabc253f1f7f6a49da-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M640,146.5 L632,134.5 648,134.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27570e3d992546eabc253f1f7f6a49da-0-7" stroke-width="2px" d="M735,144.5 C735,97.0 800.0,97.0 800.0,144.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27570e3d992546eabc253f1f7f6a49da-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735,146.5 L727,134.5 743,134.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27570e3d992546eabc253f1f7f6a49da-0-8" stroke-width="2px" d="M830,144.5 C830,97.0 895.0,97.0 895.0,144.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27570e3d992546eabc253f1f7f6a49da-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M830,146.5 L822,134.

# %%
# Export SVG files of dependency parses
from pathlib import Path
import os

a = 0
current_folder = os.getcwd() + "/images/"

for sentence in sentences_fixed:
    a+=1
    doc = nlp_english(sentence)
    svg = displacy.render(doc, style="dep", jupyter=False)
    file_name = current_folder + "/" + str(a) + ".svg"

    if not os.path.exists(current_folder):
        os.makedirs(current_folder)
    output_path = Path(file_name)
    output_path.open("w", encoding="utf-8").write(svg)
    if a==10:
        break

# %%
#Test model for other sentences (human brain)

doc = 'The human brain is the central organ of the human nervous system, and with the spinal cord makes up the central nervous system. The brain consists of the cerebrum, the brainstem and the cerebellum. It controls most of the activities of the body, processing, integrating, and coordinating the information it receives from the sense organs, and making decisions as to the instructions sent to the rest of the body. The brain is contained in, and protected by, the skull bones of the head.'.split()

doc_vector = lda_model.id2word.doc2bow(doc)
doc_topics = lda_model[doc_vector]
print('Here is the predicted weight of each topic:')
doc_topics
# Out:
# Here is the predicted weight of each topic:
# [(9, 0.94982547)]

# %%
#Test model for other sentences (classic guitar)

doc = 'The classical guitar (also known as the classic guitar) is a member of the guitar family used in classical music. An acoustic wooden string instrument with strings made of gut or nylon, it is a precursor of the modern acoustic and electric guitars, both of which use metal strings. Classical guitars are derived from the Spanish vihuela and gittern in the fifteenth and sixteenth century, which later evolved into the seventeenth and eighteenth-century Baroque guitar and later the modern classical guitar in the mid-nineteenth century.'.split()

doc_vector = lda_model.id2word.doc2bow(doc)
doc_topics = lda_model[doc_vector]
print('Here is the predicted weight of each topic:')
doc_topics
# Out:
# Here is the predicted weight of each topic:
# [(9, 0.8795259), (10, 0.07533508)]
